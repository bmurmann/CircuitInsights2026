# %%
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
from pygmid import Lookup as lk

# %%
vov = np.linspace(0.02, 0.5, num=100)
gm_id = 1/vov
gm_gds = 1/vov

plt.plot(vov, gm_id)
plt.xlabel("$V_{OV}$ (V)")
plt.ylabel("FoM (a.u.)")
plt.grid(True)
plt.show()
