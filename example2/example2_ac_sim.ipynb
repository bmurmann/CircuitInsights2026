# %%
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('./xschem/simulations/example2.txt', sep='\\s+')
df
# Out:
#         frequency   vod_mag
# 0    1.000000e+00  4.215000
# 1    1.122000e+00  4.215000
# 2    1.259000e+00  4.215000
# 3    1.413000e+00  4.215000
# 4    1.585000e+00  4.215000
# ..            ...       ...
# 196  6.310000e+09  0.021660
# 197  7.079000e+09  0.017560
# 198  7.943000e+09  0.014220
# 199  8.913000e+09  0.011500
# 200  1.000000e+10  0.009309
#
# [201 rows x 2 columns]

# %%
f = df['frequency']
mag = df['vod_mag']
mag_db = 20*np.log10(mag)
mag_db_max = np.max(mag_db)

f_calc = [2e6, 65.9e6]
mag_db_calc = [12, mag_db_max-3]

plt.semilogx(f, mag_db, label='Simulation', color='blue', linestyle='-')
plt.semilogx(f_calc, mag_db_calc, label='Calculation', marker='+', markersize=15, markeredgewidth=2, linestyle='None', color='black')
plt.xlim(1e6, 1e10)
#plt.ylim(0, 35)
plt.xlabel("f (Hz)", fontsize=18)
plt.ylabel("Magnitude (dB)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(True)
plt.legend(fontsize=14, loc='lower left')
plt.show()
